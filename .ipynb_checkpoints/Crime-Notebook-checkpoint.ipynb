# %% [markdown]
# ## Introduction
# For my metric, I decide to use the police incident reports to determine which neighborhoods are the most secure to live in. Crime is always important to consider when determining the quality of a neighborhood. Communities with the least amount of crime are therefore the most desirable.
#
# ## Metric
# My metric will create an ascending bar graph of communities and their respective crime rates. The neighborhoods with the least amount of crime (i.e. at the beginning of the graph) will be the most desirable and weighted heavily above the others in our final equation:

# %%
import pandas as pd
import numpy as np
crime = pd.read_csv("crime-stats.csv")
crime_vs_neighborhood = {}
for row in range(crime.shape[0]):
    neighborhood = crime.iloc[row][7]
    if(neighborhood != None):
        crime_vs_neighborhood[neighborhood] = 0 if(neighborhood not in crime_vs_neighborhood) else crime_vs_neighborhood[neighborhood] + 1
    
print(crime_vs_neighborhood[""])
# creating the dict with each neighborhood being a key, and their value being the amount of crimes reported there.

# %%
print(crime_vs_neighborhood)
del crime_vs_neighborhood[nan]
# for some reason, this dictionary has some values populated as 'nan' which breaks the data visualization. i delete them here.
# Out:
# {'North Shore': 505, 'Upper Lawrenceville': 208, 'Northview Heights': 286, 'Golden Triangle/Civic Arena': 2265, 'South Side Flats': 2816, 'Elliott': 367, 'Homewood North': 601, 'South Side Slopes': 602, 'Carrick': 1450, 'South Oakland': 297, nan: 672, 'Bloomfield': 1150, 'Beechview': 702, 'Bluff': 498, 'Strip District': 443, 'Mount Washington': 866, 'East Carnegie': 69, 'Crafton Heights': 343, 'Marshall-Shadeland': 685, 'East Liberty': 1044, 'East Allegheny': 832, 'Friendship': 197, 'Arlington': 242, 'Central Northside': 439, 'Spring Hill-City View': 324, 'Brighton Heights': 791, 'Westwood': 223, 'East Hills': 633, 'Brookline': 938, 'South Shore': 172, 'Lower Lawrenceville': 337, 'Bedford Dwellings': 209, 'Troy Hill-Herrs Island': 251, 'Central Oakland': 777, 'Garfield': 464, 'West End': 151, 'West Oakland': 227, 'Central Lawrenceville': 508, 'Lincoln-Lemington-Belmar': 800, 'Sheraden': 719, 'Beltzhoover': 243, 'Outside City': 249, 'Squirrel Hill South': 846, 'North Oakland': 541, 'Allentown': 731, 'Perry North': 362, 'Homewood South': 791, 'Shadyside': 1067, 'Manchester': 300, 'Squirrel Hill North': 460, 'Regent Square': 72, 'Homewood West': 307, 'Allegheny Center': 452, 'Highland Park': 681, 'Middle Hill': 431, 'Overbrook': 245, 'Hazelwood': 607, 'Greenfield': 447, 'Morningside': 216, 'Knoxville': 826, 'Point Breeze': 350, 'Duquesne Heights': 146, 'Perry South': 471, 'California-Kirkbride': 204, 'Banksville': 266, 'Point Breeze North': 321, 'Bon Air': 156, 'Polish Hill': 116, 'Lincoln Place': 167, 'Fineview': 272, 'Spring Garden': 152, 'Larimer': 449, 'Esplen': 94, 'Terrace Village': 151, 'Allegheny West': 170, 'Crawford-Roberts': 403, 'Windgap': 119, 'Stanton Heights': 244, 'Glen Hazel': 89, 'Upper Hill': 189, 'Hays': 57, 'Ridgemont': 32, 'Oakwood': 83, 'Outside State': 29, 'Chateau': 302, 'Swisshelm Park': 47, 'Outside County': 31, 'Fairywood': 88, 'Chartiers City': 25, 'Arlington Heights': 54, 'St. Clair': 78, 'Summer Hill': 64, 'Mt. Oliver Neighborhood': 55, 'New Homestead': 41, 'Mt. Oliver Boro': 11, 'Central Business District': 501, 'Troy Hill': 78, 'Central North Side': 120, 'Mount Oliver': 16}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-d1bc25b94537> in <module>
#       1 print(crime_vs_neighborhood)
# ----> 2 del crime_vs_neighborhood[nan]
#
# NameError: name 'nan' is not defined

# %%
import matplotlib.pyplot as plt


crime_vals_sorted = dict(sorted(crime_vs_neighborhood.items(), key= lambda x:x[1])) # sorting
crime_vals_sorted_abridged = {}

c = 0
for key in crime_vals_sorted.keys():
    if(c == 30):
        break
    crime_vals_sorted_abridged[key] = crime_vals_sorted[key]
    c += 1
    
print(crime_vals_sorted_abridged)

neighborhoods = list(crime_vals_sorted_abridged.keys())
num_crimes = list(crime_vals_sorted_abridged.values())

fig = plt.figure(figsize = (50, 20))

plt.bar(range(len(crime_vals_sorted_abridged)), num_crimes, tick_label = neighborhoods)
plt.xlabel("Neighborhood")
plt.ylabel("# of Crimes")
plt.title("Crime vs Neighborhoods")
plt.show()
# Out:
# {'Mt. Oliver Boro': 11, 'Mount Oliver': 16, 'Chartiers City': 25, 'Outside State': 29, 'Outside County': 31, 'Ridgemont': 32, 'New Homestead': 41, 'Swisshelm Park': 47, 'Arlington Heights': 54, 'Mt. Oliver Neighborhood': 55, 'Hays': 57, 'Summer Hill': 64, 'East Carnegie': 69, 'Regent Square': 72, 'St. Clair': 78, 'Troy Hill': 78, 'Oakwood': 83, 'Fairywood': 88, 'Glen Hazel': 89, 'Esplen': 94, 'Polish Hill': 116, 'Windgap': 119, 'Central North Side': 120, 'Duquesne Heights': 146, 'West End': 151, 'Terrace Village': 151, 'Spring Garden': 152, 'Bon Air': 156, 'Lincoln Place': 167, 'Allegheny West': 170}

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, there are many neighborhoods that have low crime rates. These neighborhoods are the most desirable to live in.
